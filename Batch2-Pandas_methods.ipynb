# %%
import pandas as pd

# %%
df = pd.read_csv("/content/train.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# **iloc**

# %%
df.iloc[0:2,0:3]
# Out:
#    PassengerId  Survived  Pclass
# 0            1         0       3
# 1            2         1       1

# %%
df.iloc[[0,1],[2,1,0]]
# Out:
#    Pclass  Survived  PassengerId
# 0       3         0            1
# 1       1         1            2

# %%
df.iloc[3]
# Out:
# PassengerId                                               4
# Survived                                                  1
# Pclass                                                    1
# Name           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# Sex                                                  female
# Age                                                    35.0
# SibSp                                                     1
# Parch                                                     0
# Ticket                                               113803
# Fare                                                   53.1
# Cabin                                                  C123
# Embarked                                                  S
# Name: 3, dtype: object

# %%
df.iloc[3,0:5]
# Out:
# PassengerId                                               4
# Survived                                                  1
# Pclass                                                    1
# Name           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# Sex                                                  female
# Name: 3, dtype: object

# %%
df.iloc[2,[3,4]]
# Out:
# Name    Heikkinen, Miss. Laina
# Sex                     female
# Name: 2, dtype: object

# %%
df.iloc[2,3:5]
# Out:
# Name    Heikkinen, Miss. Laina
# Sex                     female
# Name: 2, dtype: object

# %%
df.iloc[100,4:1]
# Out:
# Series([], Name: 100, dtype: object)

# %%
df.iloc[100,[4,3,2,7]]
# Out:
# Sex                        female
# Name      Petranec, Miss. Matilda
# Pclass                          3
# Parch                           0
# Name: 100, dtype: object

# %%
df.set_index("Ticket",inplace=True)
df
# Out:
#                   PassengerId  Survived  Pclass  \
# Ticket
# A/5 21171                   1         0       3
# PC 17599                    2         1       1
# STON/O2. 3101282            3         1       3
# 113803                      4         1       1
# 373450                      5         0       3
# ...                       ...       ...     ...
# 211536                    887         0       2
# 112053                    888         1       1
# W./C. 6607                889         0       3
# 111369                    890         1       1
# 370376                    891         0       3
#
#                                                                Name     Sex  \
# Ticket
# A/5 21171                                   Braund, Mr. Owen Harris    male
# PC 17599          Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# STON/O2. 3101282                             Heikkinen, Miss. Laina  female
# ...

# %%
df.loc["112053"]
# Out:
# PassengerId                             888
# Survived                                  1
# Pclass                                    1
# Name           Graham, Miss. Margaret Edith
# Sex                                  female
# SibSp                                     0
# Parch                                     0
# Fare                                   30.0
# Cabin                                   B42
# Embarked                                  S
# Name: 112053, dtype: object

# %%
df.loc["112053",0:3]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1361737718.py in <cell line: 0>()
# ----> 1 df.loc["112053",0:3]
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1182             if self._is_scalar_access(key):
#    1183                 return self.obj._get_value(*key, takeable=self._takeable)
# -> 1184             return self._getitem_tuple(key)
#    1185         else:
#    1186             # we by definition only have the 0th axis
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1366         with suppress(IndexingError):
#    1367             tup = self._expand_ellipsis(tup)
# -> 1368             return self._getitem_lowerdim(tup)
#    1369
#    1370         # no multi-index, so validate all of the indexers
#
# ...

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.iloc[0:5,0:5]
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex
# 0                            Braund, Mr. Owen Harris    male
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                             Heikkinen, Miss. Laina  female
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                           Allen, Mr. William Henry    male

# %%
df.loc[0:5,["PassengerId","Survived","Pclass","Name","Sex"]]
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
#
#                                                 Name     Sex
# 0                            Braund, Mr. Owen Harris    male
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                             Heikkinen, Miss. Laina  female
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                           Allen, Mr. William Henry    male
# 5                                   Moran, Mr. James    male

# %% [markdown]
# # **Data Analysis on zomato dataset**

# %%
df = pd.read_csv("/content/zomato.csv",nrows=4900)

# %%
df
# Out:
#                                                     url  \
# 0     https://www.zomato.com/bangalore/jalsa-banasha...
# 1     https://www.zomato.com/bangalore/spice-elephan...
# 2     https://www.zomato.com/SanchurroBangalore?cont...
# 3     https://www.zomato.com/bangalore/addhuri-udupi...
# 4     https://www.zomato.com/bangalore/grand-village...
# ...                                                 ...
# 4895  https://www.zomato.com/bangalore/foodies-hub-s...
# 4896  https://www.zomato.com/bangalore/sardar-ka-chu...
# 4897  https://www.zomato.com/bangalore/pizza-stop-sa...
# 4898  https://www.zomato.com/bangalore/rampyari-chai...
# 4899  https://www.zomato.com/bangalore/a-la-carte-re...
#
#                                                 address  \
# 0     942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1     2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2     1112, Next to KIMS Medical College, 17th Cross...
# 3     1st Floor, Annakuteera, 3rd Stage, Banashankar...
# ...

# %%
df.columns
# Out:
# Index(['url', 'address', 'name', 'online_order', 'book_table', 'rate', 'votes',
#        'phone', 'location', 'rest_type', 'dish_liked', 'cuisines',
#        'approx_cost(for two people)', 'reviews_list', 'menu_item',
#        'listed_in(type)', 'listed_in(city)'],
#       dtype='object')

# %%
df.shape
# Out:
# (4900, 17)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4900 entries, 0 to 4899
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   url                          4900 non-null   object
#  1   address                      4900 non-null   object
#  2   name                         4900 non-null   object
#  3   online_order                 4900 non-null   object
#  4   book_table                   4900 non-null   object
#  5   rate                         4225 non-null   object
#  6   votes                        4900 non-null   int64
#  7   phone                        4820 non-null   object
#  8   location                     4899 non-null   object
#  9   rest_type                    4876 non-null   object
#  10  dish_liked                   2008 non-null   object
#  11  cuisines                     4895 non-null   object
#  12  approx_cost(for two people)  4891 non-null   object
# ...

# %%
df.describe()
# Out:
#               votes
# count   4900.000000
# mean     194.583265
# std      592.954288
# min        0.000000
# 25%        7.000000
# 50%       36.000000
# 75%      153.000000
# max    16345.000000

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4895    False
# 4896    False
# 4897    False
# 4898    False
# 4899    False
# Length: 4900, dtype: bool

# %%
int(df.duplicated().sum())
# Out:
# 0

# %%
df["name"]
# Out:
# 0                                     Jalsa
# 1                            Spice Elephant
# 2                           San Churro Cafe
# 3                     Addhuri Udupi Bhojana
# 4                             Grand Village
#                        ...
# 4895                            Foodies Hub
# 4896                      Sardar Ka Chullah
# 4897                             Pizza Stop
# 4898    Rampyari Chaiwala Netaji Bhajiawala
# 4899                  A La Carte Restaurant
# Name: name, Length: 4900, dtype: object

# %%
df["name"].duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4895     True
# 4896     True
# 4897     True
# 4898     True
# 4899     True
# Name: name, Length: 4900, dtype: bool

# %%
int(df["name"].duplicated().sum())
# Out:
# 2522

# %%
4900-2522
# Out:
# 2378

# %%
df["name"].nunique()
# Out:
# 2378

# %%
int(df[["name","rate"]].duplicated().sum())
# Out:
# 2064

# %%
x = df[["name","rate"]].duplicated()
x
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4895     True
# 4896     True
# 4897     True
# 4898     True
# 4899     True
# Length: 4900, dtype: bool

# %%
df[x]
# Out:
#                                                     url  \
# 14    https://www.zomato.com/SanchurroBangalore?cont...
# 44    https://www.zomato.com/bangalore/onesta-banash...
# 104   https://www.zomato.com/bangalore/cafe-nova-ban...
# 193   https://www.zomato.com/bangalore/caf%C3%A9-dow...
# 199   https://www.zomato.com/bangalore/the-vintage-c...
# ...                                                 ...
# 4895  https://www.zomato.com/bangalore/foodies-hub-s...
# 4896  https://www.zomato.com/bangalore/sardar-ka-chu...
# 4897  https://www.zomato.com/bangalore/pizza-stop-sa...
# 4898  https://www.zomato.com/bangalore/rampyari-chai...
# 4899  https://www.zomato.com/bangalore/a-la-carte-re...
#
#                                                 address  \
# 14    1112, Next to KIMS Medical College, 17th Cross...
# 44    2469, 3rd Floor, 24th Cross, Opposite BDA Comp...
# 104   101, Water Tank Road, 2nd Block, 3rd Stage, Ba...
# 193   12,29 Near PES University Back Gate, D'Souza N...
# ...

# %%
df[x][["name","rate"]]
# Out:
#                                                    name   rate
# 14                                      San Churro Cafe  3.8/5
# 44                                               Onesta  4.6/5
# 104                                           CAFE NOVA  3.2/5
# 193   CafÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂ© Down The A...  4.1/5
# 199                                    The Vintage Cafe  3.0/5
# ...                                                 ...    ...
# 4895                                        Foodies Hub  3.1/5
# 4896                                  Sardar Ka Chullah    NaN
# 4897                                         Pizza Stop  3.2/5
# 4898                Rampyari Chaiwala Netaji Bhajiawala  3.1/5
# 4899                              A La Carte Restaurant    NaN
#
# [2064 rows x 2 columns]

# %%
df[x][["name","rate"]].value_counts()
# Out:
# name              rate
# San Churro Cafe   3.8/5    9
# Kirthi's Biryani  3.8/5    7
# Redberrys         4.0/5    7
# Kanti Sweets      4.0/5    6
# Smacznego         4.2/5    5
#                           ..
# Yummy Momos       3.2/5    1
# 24th Main         4.1/5    1
# 1947              4.1/5    1
#                   4.0/5    1
# eat.fit           4.5/5    1
# Name: count, Length: 1254, dtype: int64

# %%
df[df["name"]=="San Churro Cafe"].shape
# Out:
# (10, 17)

# %%
df["name"].value_counts()
# Out:
# name
# Cafe Coffee Day                 15
# Five Star Chicken               12
# New Prashanth Hotel             11
# Petoo                           11
# Polar Bear                      11
#                                 ..
# Noodles                          1
# Roll junction                    1
# Pathankot Punjabi Restaurant     1
# OPUS Club                        1
# Deli Chats & Sweets              1
# Name: count, Length: 2378, dtype: int64

# %%
df.isnull()
# Out:
#         url  address   name  online_order  book_table   rate  votes  phone  \
# 0     False    False  False         False       False  False  False  False
# 1     False    False  False         False       False  False  False  False
# 2     False    False  False         False       False  False  False  False
# 3     False    False  False         False       False  False  False  False
# 4     False    False  False         False       False  False  False  False
# ...     ...      ...    ...           ...         ...    ...    ...    ...
# 4895  False    False  False         False       False  False  False  False
# 4896  False    False  False         False       False   True  False  False
# 4897  False    False  False         False       False  False  False  False
# 4898  False    False  False         False       False  False  False  False
# 4899  False    False  False         False       False   True  False  False
#
# ...

# %%
df[["name","rate"]].isnull()
# Out:
#        name   rate
# 0     False  False
# 1     False  False
# 2     False  False
# 3     False  False
# 4     False  False
# ...     ...    ...
# 4895  False  False
# 4896  False   True
# 4897  False  False
# 4898  False  False
# 4899  False   True
#
# [4900 rows x 2 columns]

# %%
df.isnull().sum()
# Out:
# url                               0
# address                           0
# name                              0
# online_order                      0
# book_table                        0
# rate                            675
# votes                             0
# phone                            80
# location                          1
# rest_type                        24
# dish_liked                     2892
# cuisines                          5
# approx_cost(for two people)       9
# reviews_list                      0
# menu_item                         0
# listed_in(type)                   0
# listed_in(city)                   0
# dtype: int64

# %%
df.notnull()
# Out:
#        url  address  name  online_order  book_table   rate  votes  phone  \
# 0     True     True  True          True        True   True   True   True
# 1     True     True  True          True        True   True   True   True
# 2     True     True  True          True        True   True   True   True
# 3     True     True  True          True        True   True   True   True
# 4     True     True  True          True        True   True   True   True
# ...    ...      ...   ...           ...         ...    ...    ...    ...
# 4895  True     True  True          True        True   True   True   True
# 4896  True     True  True          True        True  False   True   True
# 4897  True     True  True          True        True   True   True   True
# 4898  True     True  True          True        True   True   True   True
# 4899  True     True  True          True        True  False   True   True
#
#       location  rest_type  dish_liked  cuisines  approx_cost(for two people)  \
# ...

# %%
df.notnull().sum()
# Out:
# url                            4900
# address                        4900
# name                           4900
# online_order                   4900
# book_table                     4900
# rate                           4225
# votes                          4900
# phone                          4820
# location                       4899
# rest_type                      4876
# dish_liked                     2008
# cuisines                       4895
# approx_cost(for two people)    4891
# reviews_list                   4900
# menu_item                      4900
# listed_in(type)                4900
# listed_in(city)                4900
# dtype: int64

# %%
columns_null_count_dict = df.isnull().sum().to_dict()
columns_null_count_dict
# Out:
# {'url': 0,
#  'address': 0,
#  'name': 0,
#  'online_order': 0,
#  'book_table': 0,
#  'rate': 675,
#  'votes': 0,
#  'phone': 80,
#  'location': 1,
#  'rest_type': 24,
#  'dish_liked': 2892,
#  'cuisines': 5,
#  'approx_cost(for two people)': 9,
#  'reviews_list': 0,
#  'menu_item': 0,
#  'listed_in(type)': 0,
#  'listed_in(city)': 0}

# %%
l=[]
for key, val in columns_null_count_dict.items():

  if val > 0:
    l.append(key)

print(l)
# Out:
# ['rate', 'phone', 'location', 'rest_type', 'dish_liked', 'cuisines', 'approx_cost(for two people)']

# %%
[key for key, val in columns_null_count_dict.items() if val>0]
# Out:
# ['rate',
#  'phone',
#  'location',
#  'rest_type',
#  'dish_liked',
#  'cuisines',
#  'approx_cost(for two people)']

# %%
df = df.dropna()

# %%
df.isnull().sum()
# Out:
# url                            0
# address                        0
# name                           0
# online_order                   0
# book_table                     0
# rate                           0
# votes                          0
# phone                          0
# location                       0
# rest_type                      0
# dish_liked                     0
# cuisines                       0
# approx_cost(for two people)    0
# reviews_list                   0
# menu_item                      0
# listed_in(type)                0
# listed_in(city)                0
# dtype: int64

# %%
df.shape
# Out:
# (1977, 17)

# %%
4900-1977
# Out:
# 2923

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df["name"].duplicated().sum()
# Out:
# np.int64(2522)

# %%
df.shape
# Out:
# (4900, 17)

# %%
df["name"].nunique()
# Out:
# 2378

# %%
df["name"].drop_duplicates(keep="first",inplace=True)

# %%
df.shape
# Out:
# (4900, 17)

# %% [markdown]
# #drop

# %%
df.columns
# Out:
# Index(['url', 'address', 'name', 'online_order', 'book_table', 'rate', 'votes',
#        'phone', 'location', 'rest_type', 'dish_liked', 'cuisines',
#        'approx_cost(for two people)', 'reviews_list', 'menu_item',
#        'listed_in(type)', 'listed_in(city)'],
#       dtype='object')

# %%
df.drop(columns=["listed_in(type)"],axis=1,inplace=True)

# %%
df
# Out:
#                                                     url  \
# 0     https://www.zomato.com/bangalore/jalsa-banasha...
# 1     https://www.zomato.com/bangalore/spice-elephan...
# 2     https://www.zomato.com/SanchurroBangalore?cont...
# 3     https://www.zomato.com/bangalore/addhuri-udupi...
# 4     https://www.zomato.com/bangalore/grand-village...
# ...                                                 ...
# 4895  https://www.zomato.com/bangalore/foodies-hub-s...
# 4896  https://www.zomato.com/bangalore/sardar-ka-chu...
# 4897  https://www.zomato.com/bangalore/pizza-stop-sa...
# 4898  https://www.zomato.com/bangalore/rampyari-chai...
# 4899  https://www.zomato.com/bangalore/a-la-carte-re...
#
#                                                 address  \
# 0     942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1     2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2     1112, Next to KIMS Medical College, 17th Cross...
# 3     1st Floor, Annakuteera, 3rd Stage, Banashankar...
# ...

# %%
df.drop(columns=['location', 'rest_type'],axis=1,inplace=True)
df
# Out:
#                                                     url  \
# 0     https://www.zomato.com/bangalore/jalsa-banasha...
# 1     https://www.zomato.com/bangalore/spice-elephan...
# 2     https://www.zomato.com/SanchurroBangalore?cont...
# 3     https://www.zomato.com/bangalore/addhuri-udupi...
# 4     https://www.zomato.com/bangalore/grand-village...
# ...                                                 ...
# 4895  https://www.zomato.com/bangalore/foodies-hub-s...
# 4896  https://www.zomato.com/bangalore/sardar-ka-chu...
# 4897  https://www.zomato.com/bangalore/pizza-stop-sa...
# 4898  https://www.zomato.com/bangalore/rampyari-chai...
# 4899  https://www.zomato.com/bangalore/a-la-carte-re...
#
#                                                 address  \
# 0     942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1     2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2     1112, Next to KIMS Medical College, 17th Cross...
# 3     1st Floor, Annakuteera, 3rd Stage, Banashankar...
# ...

# %%
  df.index
# Out:
# RangeIndex(start=0, stop=4900, step=1)

# %%
df.set_index("name",inplace=True)
df
# Out:
#                                                                                    url  \
# name
# Jalsa                                https://www.zomato.com/bangalore/jalsa-banasha...
# Spice Elephant                       https://www.zomato.com/bangalore/spice-elephan...
# San Churro Cafe                      https://www.zomato.com/SanchurroBangalore?cont...
# Addhuri Udupi Bhojana                https://www.zomato.com/bangalore/addhuri-udupi...
# Grand Village                        https://www.zomato.com/bangalore/grand-village...
# ...                                                                                ...
# Foodies Hub                          https://www.zomato.com/bangalore/foodies-hub-s...
# Sardar Ka Chullah                    https://www.zomato.com/bangalore/sardar-ka-chu...
# Pizza Stop                           https://www.zomato.com/bangalore/pizza-stop-sa...
# Rampyari Chaiwala Netaji Bhajiawala  https://www.zomato.com/bangalore/rampyari-chai...
# ...

# %%
df.reset_index(inplace=True)
df
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-2789198747.py in <cell line: 0>()
# ----> 1 df.reset_index(inplace=True)
#       2 df
#
# AttributeError: 'NoneType' object has no attribute 'reset_index'

# %%
df
# Out:
#                                                     url  \
# 0     https://www.zomato.com/bangalore/jalsa-banasha...
# 1     https://www.zomato.com/bangalore/spice-elephan...
# 2     https://www.zomato.com/SanchurroBangalore?cont...
# 3     https://www.zomato.com/bangalore/addhuri-udupi...
# 4     https://www.zomato.com/bangalore/grand-village...
# ...                                                 ...
# 4895  https://www.zomato.com/bangalore/foodies-hub-s...
# 4896  https://www.zomato.com/bangalore/sardar-ka-chu...
# 4897  https://www.zomato.com/bangalore/pizza-stop-sa...
# 4898  https://www.zomato.com/bangalore/rampyari-chai...
# 4899  https://www.zomato.com/bangalore/a-la-carte-re...
#
#                                                 address  \
# 0     942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1     2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2     1112, Next to KIMS Medical College, 17th Cross...
# 3     1st Floor, Annakuteera, 3rd Stage, Banashankar...
# ...

# %%
df = df.sort_values(by="votes",ascending=False).reset_index()

# %%
df
# Out:
#       index                                                url  \
# 0      3921  https://www.zomato.com/bangalore/byg-brewski-b...
# 1      4801  https://www.zomato.com/bangalore/byg-brewski-b...
# 2      4131  https://www.zomato.com/bangalore/hoot-sarjapur...
# 3      4802  https://www.zomato.com/bangalore/hoot-sarjapur...
# 4      4800  https://www.zomato.com/bangalore/the-black-pea...
# ...     ...                                                ...
# 4895     84  https://www.zomato.com/bangalore/chill-out-ban...
# 4896   3433  https://www.zomato.com/bangalore/mama-mys-cafe...
# 4897     72  https://www.zomato.com/bangalore/spicy-tandoor...
# 4898    107  https://www.zomato.com/bangalore/coffee-shopee...
# 4899    110  https://www.zomato.com/bangalore/hari-super-sa...
#
#                                                 address  \
# 0            Behind MK Retail, Sarjapur Road, Bangalore
# 1            Behind MK Retail, Sarjapur Road, Bangalore
# ...

# %%
df.drop(columns=["index"],axis=1,inplace=True)
df
# Out:
#                                                     url  \
# 0     https://www.zomato.com/bangalore/byg-brewski-b...
# 1     https://www.zomato.com/bangalore/byg-brewski-b...
# 2     https://www.zomato.com/bangalore/hoot-sarjapur...
# 3     https://www.zomato.com/bangalore/hoot-sarjapur...
# 4     https://www.zomato.com/bangalore/the-black-pea...
# ...                                                 ...
# 4895  https://www.zomato.com/bangalore/chill-out-ban...
# 4896  https://www.zomato.com/bangalore/mama-mys-cafe...
# 4897  https://www.zomato.com/bangalore/spicy-tandoor...
# 4898  https://www.zomato.com/bangalore/coffee-shopee...
# 4899  https://www.zomato.com/bangalore/hari-super-sa...
#
#                                                 address  \
# 0            Behind MK Retail, Sarjapur Road, Bangalore
# 1            Behind MK Retail, Sarjapur Road, Bangalore
# 2     2034/69, Block 2, Kaikondrahalli, Varthur Hobl...
# 3     2034/69, Block 2, Kaikondrahalli, Varthur Hobl...
# ...

# %%
df.sort_values(by=["rate","votes"],ascending=False)
# Out:
#                                                     url  \
# 3935  https://www.zomato.com/bangalore/fabcafe-jayan...
# 3936  https://www.zomato.com/bangalore/cafe-terra-ja...
# 3944  https://www.zomato.com/bangalore/spicy-tandoor...
# 3945  https://www.zomato.com/bangalore/dose-manjanna...
# 3953  https://www.zomato.com/bangalore/ambur-dum-bir...
# ...                                                 ...
# 4889  https://www.zomato.com/bangalore/smm-pizzeria-...
# 4890  https://www.zomato.com/bangalore/jhanavi-resta...
# 4894  https://www.zomato.com/bangalore/cake-bite-ban...
# 4895  https://www.zomato.com/bangalore/chill-out-ban...
# 4898  https://www.zomato.com/bangalore/coffee-shopee...
#
#                                                 address                name  \
# 3935  5, Diagonal Road, 3rd Block, 1st Floor, Jayana...             Fabcafe
# 3936  138, 6th C Main Road, 4th Block, Jayanagar, Ba...          Cafe Terra
# ...

# %%
df
# Out:
#                                                     url  \
# 0     https://www.zomato.com/bangalore/byg-brewski-b...
# 1     https://www.zomato.com/bangalore/byg-brewski-b...
# 2     https://www.zomato.com/bangalore/hoot-sarjapur...
# 3     https://www.zomato.com/bangalore/hoot-sarjapur...
# 4     https://www.zomato.com/bangalore/the-black-pea...
# ...                                                 ...
# 4895  https://www.zomato.com/bangalore/chill-out-ban...
# 4896  https://www.zomato.com/bangalore/mama-mys-cafe...
# 4897  https://www.zomato.com/bangalore/spicy-tandoor...
# 4898  https://www.zomato.com/bangalore/coffee-shopee...
# 4899  https://www.zomato.com/bangalore/hari-super-sa...
#
#                                                 address  \
# 0            Behind MK Retail, Sarjapur Road, Bangalore
# 1            Behind MK Retail, Sarjapur Road, Bangalore
# 2     2034/69, Block 2, Kaikondrahalli, Varthur Hobl...
# 3     2034/69, Block 2, Kaikondrahalli, Varthur Hobl...
# ...

# %%
df["rate"].unique()
# Out:
# array(['4.9/5', '4.2/5', '4.8/5', '4.4 /5', '4.4/5', '4.5 /5', '4.7/5',
#        '4.5/5', '4.3/5', '4.1/5', '4.6/5', '4.1 /5', '3.8/5', '4.2 /5',
#        '4.0/5', '3.9/5', '4.3 /5', '4.0 /5', '3.7/5', '2.9/5', '3.6/5',
#        '3.9 /5', '3.4/5', '3.3/5', '3.5/5', '2.8/5', '2.6/5', '2.4/5',
#        '3.7 /5', '2.7/5', '3.2/5', '3.0/5', '2.1/5', '2.5/5', '3.1/5',
#        '2.3/5', '2.2/5', '3.8 /5', '3.5 /5', '2.9 /5', '2.6 /5', '2.7 /5',
#        '3.6 /5', '2.5 /5', '2.8 /5', '3.3 /5', '3.1 /5', '3.4 /5',
#        '3.2 /5', nan, '-', 'NEW'], dtype=object)

# %%
import numpy as np

# %%
df["rate"].isin([np.nan,"-","NEW"])
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4895     True
# 4896     True
# 4897     True
# 4898     True
# 4899     True
# Name: rate, Length: 4900, dtype: bool

# %%
~df["rate"].isin([np.nan,"-","NEW"])
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 4895    False
# 4896    False
# 4897    False
# 4898    False
# 4899    False
# Name: rate, Length: 4900, dtype: bool

# %%
df =df[~df["rate"].isin([np.nan,"-","NEW"])]

# %%
df
# Out:
#                                                     url  \
# 0     https://www.zomato.com/bangalore/byg-brewski-b...
# 1     https://www.zomato.com/bangalore/byg-brewski-b...
# 2     https://www.zomato.com/bangalore/hoot-sarjapur...
# 3     https://www.zomato.com/bangalore/hoot-sarjapur...
# 4     https://www.zomato.com/bangalore/the-black-pea...
# ...                                                 ...
# 3927  https://www.zomato.com/bangalore/garage-pizza-...
# 3928  https://www.zomato.com/bangalore/wimpie-sarjap...
# 3929  https://www.zomato.com/bangalore/katriguppe-do...
# 3930  https://www.zomato.com/bangalore/ultra-biriyan...
# 4842  https://www.zomato.com/bangalore/starlite-bake...
#
#                                                 address  \
# 0            Behind MK Retail, Sarjapur Road, Bangalore
# 1            Behind MK Retail, Sarjapur Road, Bangalore
# 2     2034/69, Block 2, Kaikondrahalli, Varthur Hobl...
# 3     2034/69, Block 2, Kaikondrahalli, Varthur Hobl...
# ...

# %%
df["rate"].unique()
# Out:
# array(['4.9/5', '4.2/5', '4.8/5', '4.4 /5', '4.4/5', '4.5 /5', '4.7/5',
#        '4.5/5', '4.3/5', '4.1/5', '4.6/5', '4.1 /5', '3.8/5', '4.2 /5',
#        '4.0/5', '3.9/5', '4.3 /5', '4.0 /5', '3.7/5', '2.9/5', '3.6/5',
#        '3.9 /5', '3.4/5', '3.3/5', '3.5/5', '2.8/5', '2.6/5', '2.4/5',
#        '3.7 /5', '2.7/5', '3.2/5', '3.0/5', '2.1/5', '2.5/5', '3.1/5',
#        '2.3/5', '2.2/5', '3.8 /5', '3.5 /5', '2.9 /5', '2.6 /5', '2.7 /5',
#        '3.6 /5', '2.5 /5', '2.8 /5', '3.3 /5', '3.1 /5', '3.4 /5',
#        '3.2 /5'], dtype=object)

# %%
df["rate"] = df["rate"].apply(lambda x: eval(x.split("/")[0].strip()))
# Out:
# /tmp/ipython-input-427680675.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["rate"] = df["rate"].apply(lambda x: eval(x.split("/")[0].strip()))

# %%
df
# Out:
#                                                     url  \
# 0     https://www.zomato.com/bangalore/byg-brewski-b...
# 1     https://www.zomato.com/bangalore/byg-brewski-b...
# 2     https://www.zomato.com/bangalore/hoot-sarjapur...
# 3     https://www.zomato.com/bangalore/hoot-sarjapur...
# 4     https://www.zomato.com/bangalore/the-black-pea...
# ...                                                 ...
# 3927  https://www.zomato.com/bangalore/garage-pizza-...
# 3928  https://www.zomato.com/bangalore/wimpie-sarjap...
# 3929  https://www.zomato.com/bangalore/katriguppe-do...
# 3930  https://www.zomato.com/bangalore/ultra-biriyan...
# 4842  https://www.zomato.com/bangalore/starlite-bake...
#
#                                                 address  \
# 0            Behind MK Retail, Sarjapur Road, Bangalore
# 1            Behind MK Retail, Sarjapur Road, Bangalore
# 2     2034/69, Block 2, Kaikondrahalli, Varthur Hobl...
# 3     2034/69, Block 2, Kaikondrahalli, Varthur Hobl...
# ...

# %%
df["rate"].unique()
# Out:
# array([4.9, 4.2, 4.8, 4.4, 4.5, 4.7, 4.3, 4.1, 4.6, 3.8, 4. , 3.9, 3.7,
#        2.9, 3.6, 3.4, 3.3, 3.5, 2.8, 2.6, 2.4, 2.7, 3.2, 3. , 2.1, 2.5,
#        3.1, 2.3, 2.2])

# %%
df.dtypes
# Out:
# url                             object
# address                         object
# name                            object
# online_order                    object
# book_table                      object
# rate                           float64
# votes                            int64
# phone                           object
# location                        object
# rest_type                       object
# dish_liked                      object
# cuisines                        object
# approx_cost(for two people)     object
# reviews_list                    object
# menu_item                       object
# listed_in(type)                 object
# listed_in(city)                 object
# dtype: object

# %%
x= '4.5 /5'
# type(eval(x.split("/")[0].strip()))
eval(x.split("/")[0].strip())
# Out:
# 4.5

# %%
df.sort_values(by="rate",ascending=False)
# Out:
#                                                     url  \
# 0     https://www.zomato.com/bangalore/byg-brewski-b...
# 1     https://www.zomato.com/bangalore/byg-brewski-b...
# 5     https://www.zomato.com/bangalore/the-black-pea...
# 4     https://www.zomato.com/bangalore/the-black-pea...
# 43    https://www.zomato.com/bangalore/brahmins-coff...
# ...                                                 ...
# 1673  https://www.zomato.com/bangalore/tandoor-hut-b...
# 1679  https://www.zomato.com/bangalore/tandoor-hut-b...
# 1043  https://www.zomato.com/bangalore/madurai-idly-...
# 648   https://www.zomato.com/bangalore/mast-kalandar...
# 652   https://www.zomato.com/bangalore/mast-kalandar...
#
#                                                 address  \
# 0            Behind MK Retail, Sarjapur Road, Bangalore
# 1            Behind MK Retail, Sarjapur Road, Bangalore
# 5     20/7, Swamy Legato, Outer Ring Road, Kadubeesa...
# 4     20/7, Swamy Legato, Outer Ring Road, Kadubeesa...
# ...

# %%
df.sort_values(by=["rate","votes"],ascending=False)
# Out:
#                                                     url  \
# 0     https://www.zomato.com/bangalore/byg-brewski-b...
# 1     https://www.zomato.com/bangalore/byg-brewski-b...
# 4     https://www.zomato.com/bangalore/the-black-pea...
# 5     https://www.zomato.com/bangalore/the-black-pea...
# 43    https://www.zomato.com/bangalore/brahmins-coff...
# ...                                                 ...
# 1043  https://www.zomato.com/bangalore/madurai-idly-...
# 1673  https://www.zomato.com/bangalore/tandoor-hut-b...
# 1679  https://www.zomato.com/bangalore/tandoor-hut-b...
# 648   https://www.zomato.com/bangalore/mast-kalandar...
# 652   https://www.zomato.com/bangalore/mast-kalandar...
#
#                                                 address  \
# 0            Behind MK Retail, Sarjapur Road, Bangalore
# 1            Behind MK Retail, Sarjapur Road, Bangalore
# 4     20/7, Swamy Legato, Outer Ring Road, Kadubeesa...
# 5     20/7, Swamy Legato, Outer Ring Road, Kadubeesa...
# ...

# %%
df.sort_values(by=["votes","rate"],ascending=False)
# Out:
#                                                     url  \
# 0     https://www.zomato.com/bangalore/byg-brewski-b...
# 1     https://www.zomato.com/bangalore/byg-brewski-b...
# 2     https://www.zomato.com/bangalore/hoot-sarjapur...
# 3     https://www.zomato.com/bangalore/hoot-sarjapur...
# 4     https://www.zomato.com/bangalore/the-black-pea...
# ...                                                 ...
# 3904  https://www.zomato.com/bangalore/thalassery-fo...
# 3909  https://www.zomato.com/bangalore/slice-of-spic...
# 3906  https://www.zomato.com/bangalore/american-bite...
# 3887  https://www.zomato.com/bangalore/special-biriy...
# 4842  https://www.zomato.com/bangalore/starlite-bake...
#
#                                                 address  \
# 0            Behind MK Retail, Sarjapur Road, Bangalore
# 1            Behind MK Retail, Sarjapur Road, Bangalore
# 2     2034/69, Block 2, Kaikondrahalli, Varthur Hobl...
# 3     2034/69, Block 2, Kaikondrahalli, Varthur Hobl...
# ...

# %%
df[["location","name"]].value_counts()
# Out:
# location      name
# Banashankari  San Churro Cafe                  10
# Basavanagudi  Redberrys                         8
# Banashankari  Kirthi's Biryani                  8
#               360 Atoms Restaurant And Cafe     6
#               Penthouse Cafe                    6
#                                                ..
# Uttarahalli   Potato House                      1
# BTM           Biriyani Angadi                   1
#               Birinz                            1
#               Bawarchi Inn                      1
#               Basmati Delights                  1
# Name: count, Length: 2155, dtype: int64

# %%
df.rename(columns={"rate":"rate(5)"},inplace=True)
df
# Out:
# /tmp/ipython-input-3551060022.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns={"rate":"rate(5)"},inplace=True)
#                                                     url  \
# 0     https://www.zomato.com/bangalore/byg-brewski-b...
# 1     https://www.zomato.com/bangalore/byg-brewski-b...
# 2     https://www.zomato.com/bangalore/hoot-sarjapur...
# 3     https://www.zomato.com/bangalore/hoot-sarjapur...
# 4     https://www.zomato.com/bangalore/the-black-pea...
# ...                                                 ...
# 3927  https://www.zomato.com/bangalore/garage-pizza-...
# 3928  https://www.zomato.com/bangalore/wimpie-sarjap...
# 3929  https://www.zomato.com/bangalore/katriguppe-do...
# 3930  https://www.zomato.com/bangalore/ultra-biriyan...
# ...

# %%
import numpy as np
import pandas as pd

# %%
data = {
    "devices":["A","B","C","A","C","D","A","Z","D"],
    "prices":np.random.randint(1,100,size=9)
}
data
# Out:
# {'devices': ['A', 'B', 'C', 'A', 'C', 'D', 'A', 'Z', 'D'],
#  'prices': array([79,  8, 53, 94, 84, 61, 70, 57, 97])}

# %%
df= pd.DataFrame(data)
df
# Out:
#   devices  prices
# 0       A      79
# 1       B       8
# 2       C      53
# 3       A      94
# 4       C      84
# 5       D      61
# 6       A      70
# 7       Z      57
# 8       D      97

# %%
df.drop_duplicates(keep="first",inplace=True,ignore_index=True)

# %%
df
# Out:
#   devices  prices
# 0       A      79
# 1       B       8
# 2       C      53
# 3       A      94
# 4       C      84
# 5       D      61
# 6       A      70
# 7       Z      57
# 8       D      97
